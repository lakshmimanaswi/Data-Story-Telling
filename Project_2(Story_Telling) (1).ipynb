# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
print("Dataset Shape:", df.shape)
df.head()

# %%
df.info()

# %%
df.describe(include='all')

# %%
print("Duplicate Rows:", df.duplicated().sum())

# %%
df.drop_duplicates(inplace=True)
df['country'] = df['country'].fillna('Unknown')
df['rating'] = df['rating'].fillna('Not Rated')
df['listed_in'] = df['listed_in'].fillna('Unknown')

# %%
plt.figure(figsize=(6,4))
df['type'].value_counts().plot(kind='bar')
plt.title('Movies vs TV Shows')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12,5))
df['release_year'].value_counts().sort_index().plot()
plt.title('Content Released by Year')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['country'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Countries Producing Netflix Content')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['rating'].value_counts().plot(kind='bar')
plt.title('Ratings Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
genres = df['listed_in'].str.split(', ').explode()
plt.figure(figsize=(12,5))
genres.value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 📈Insights and Findings
#
# The analysis revealed several important patterns within the dataset. Movies were found to be more common than TV Shows, indicating a greater focus on movie content. The number of releases increased over the years, showing continuous growth in content production. Content was contributed by multiple countries, highlighting the platform's global reach and diverse audience. Popular genres such as Drama, Comedy, and Action appeared frequently, suggesting strong viewer interest in these categories. Overall, the visualizations helped identify trends, compare categories, and better understand the distribution of content across different dimensions.

# %% [markdown]
# 🎯 Conclusion and Recommendations
#
# The data storytelling project successfully transformed raw data into meaningful insights through exploratory analysis and visualizations. The findings showed growth in content production, diversity in genres, and contributions from various countries. These trends indicate the importance of maintaining a diverse content library to meet audience preferences.
#
# Recommendations
# Continue investing in popular genres to improve audience engagement.
# Expand content production in underrepresented regions to reach broader audiences.
# Maintain a balanced mix of movies and TV shows.
# Use data-driven insights to guide future content decisions.
# Regularly monitor trends and audience preferences to stay competitive.
